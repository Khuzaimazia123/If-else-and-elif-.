# %%
Toys= 0
if Toys >= 9:
    print ("You should distribute toys to others")
elif Toys == 7:
   print ("You have enough toys")
elif Toys <= 4:
   print("You should get more toys")
# Out:
# You should get more toys
